# %%
import pandas as pd
import matplotlib

# %%
file = '../covid-data.csv'
df = pd.read_csv(file)
print(df.head())
# Out:
#                                        MMSA total_percent_at_risk  \
# 0              San Juan-Carolina-Caguas, PR                52.88%
# 1                             Manhattan, KS                47.29%
# 2  Hilton Head Island-Bluffton-Beaufort, SC                62.72%
# 3               Kahului-Wailuku-Lahaina, HI                59.13%
# 4                           Spartanburg, SC                66.12%
#
#    high_risk_per_ICU_bed  high_risk_per_hospital  icu_beds  hospitals  \
# 0                    NaN                     NaN       NaN        NaN
# 1            4489.848750               8979.6975       8.0        4.0
# 2            3904.163571              36438.8600      28.0        3.0
# 3            3860.557000              19302.7850      20.0        4.0
# 4            3786.115556              85187.6000      45.0        2.0
#
#    total_at_risk
# 0     923725.203
# 1      35918.790
# 2     109316.580
# 3      77211.140
# 4     170375.200

# %%
by_mmsa_mean = df.groupby('MMSA')[['hospitals']].mean()
print(by_mmsa_mean['hospitals'])
# Out:
# MMSA
# Aberdeen, SD                                                            3.0
# Albany-Schenectady-Troy, NY                                            10.0
# Albuquerque, NM                                                         6.0
# Allentown-Bethlehem-Easton, PA-NJ                                      11.0
# Anchorage, AK                                                           4.0
#                                                                        ...
# Washington-Arlington-Alexandria, DC-VA-MD-WV, Metropolitan Division    32.0
# Wichita Falls, TX                                                       4.0
# Wichita, KS                                                            12.0
# Wilmington, DE-MD-NJ, Metropolitan Division                             5.0
# Worcester, MA-CT                                                       10.0
# Name: hospitals, Length: 136, dtype: float64

# %%
by_MMSA_median = df.groupby('MMSA')[['icu_beds']].median()
print(by_MMSA_median['icu_beds'])
plt.hist(by_MMSA_median['icu_beds'])
# Out:
# MMSA
# Aberdeen, SD                                                            10.0
# Albany-Schenectady-Troy, NY                                            187.0
# Albuquerque, NM                                                        138.0
# Allentown-Bethlehem-Easton, PA-NJ                                      240.0
# Anchorage, AK                                                           87.0
#                                                                        ...
# Washington-Arlington-Alexandria, DC-VA-MD-WV, Metropolitan Division    804.0
# Wichita Falls, TX                                                       24.0
# Wichita, KS                                                            258.0
# Wilmington, DE-MD-NJ, Metropolitan Division                            143.0
# Worcester, MA-CT                                                       175.0
# Name: icu_beds, Length: 136, dtype: float64
# (array([80., 30., 14.,  5.,  2.,  1.,  0.,  0.,  1.,  2.]),
# ...

# %%
by_MMSA_median.plot(kind='bar', title='Mean Hospital Number by MMSA', ylabel='Mean Hospital Number',
         xlabel='MMSA', figsize=(100, 80))
# Out:
# <AxesSubplot:title={'center':'Mean Hospital Number by MMSA'}, xlabel='MMSA', ylabel='Mean Hospital Number'>

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

data = file

# %%
plt.hist(by_mmsa_mean['hospitals'])
# Out:
# (array([77., 32., 13.,  7.,  2.,  1.,  0.,  0.,  2.,  1.]),
#  array([  1. ,  10.9,  20.8,  30.7,  40.6,  50.5,  60.4,  70.3,  80.2,
#          90.1, 100. ]),
#  <BarContainer object of 10 artists>)
